# %%
import CSV
using DataFrames
# using StatsBase
include("$( dirname(dirname(pwd())) )/pred_funcs.jl")
using MLJ
# import MLJBase
import TableView.showtable
using Plots
import FileIO
import Statistics
import LinearAlgebra
using StatsPlots
using Random
Random.seed!(0);
using StatsBase
import MLJBase
# Out:
# WebIO._IJuliaInit()

# %%
MissingImputator = @load MissingImputator pkg="BetaML" verbosity=0
LogisticClassifier = @load LogisticClassifier pkg="MLJLinearModels" verbosity=0;  # loads code defining a model type
EvoTreeClassifier = @load EvoTreeClassifier verbosity=0
# Out:
# EvoTrees.EvoTreeClassifier

# %%
full = ""
# Out:
# ""

# %%
sample_key2, xold, yold = FileIO.load("$(dirname(dirname(pwd())))/data$(full).jld2","sample_key","x" ,"y");


xold.col1=collect(1:nrow(xold));
println(nrow(xold))
filter!(x->x.ALTREF_I ≈ 1,xold)
println(nrow(xold))
# filter!(x->x.ALT_I>0.5 || x.REF_I>0.5,xold) # indel
# filter!(x->x.ALT_I<0.5 && x.REF_I<0.5,xold) # SNV
println(nrow(xold))
filter!(x->x.training>0.5,xold)
# select!(xold,Not("training"));
println(nrow(xold))
# filter!(x->!ismissing(x.dust_score_Mutect),xold);
# println(nrow(xold))

yold = yold[xold.col1]
# println(xold[findall(x->x,[i==true for i in yold]),"col1"])
# println(xold[findall(x->!x,[i==true for i in yold]),"col1"])
sample_key2 = sample_key2[xold.col1]
select!(xold,Not("col1"));
# Out:
# 94626
# 15006
# 15006
# 6480

# %%
for j in 1:ncol(xold), i in 1:nrow(xold)
    if !ismissing(xold[i,j]) && (isnan(xold[i,j]) || isinf(xold[i,j]) )
        xold[i,j] = missing
    end
end

# %%
train2 = 1:nrow(xold)
# train2, test2 = partition(eachindex(yold), 0.5, stratify=yold,  shuffle=true, rng=12344);

select!(xold,Not("training"));

# %%
sum([i==true for i in yold[train2]])
# Out:
# 15

# %%
# sum([i==true for i in yold[test2]])

# %%
sum(.~ismissing.(xold[train2,:dust_score_Vardict]))
# Out:
# 935

# %%
# FileIO.save("testdata$(full).jld2", Dict("sample_key"=>sample_key2[test2],"x" => xold[test2,:],
#         "y" => yold[test2], 
#     ) ; compress = true
# )
FileIO.save("traindata$(full).jld2", Dict("sample_key"=>sample_key2[train2],"x" => xold[train2,:],
        "y" => yold[train2], 
    ) ; compress = true
)

# %% [markdown]
# # Mutect

# %%
x = copy(xold[train2,:]);
y = copy(yold[train2]);

# %%
x.col1=collect(1:nrow(x));
coldrop = [] #"FPpass","FILTER_Mutect_PASS"] # ["gt_AF_Mutect","AltFwd_Mutect","RefFwd_Mutect","AltRev_Mutect","RefRev_Mutect","gt_AD_ref_Mutect","gt_AD_alt_Mutect"]
for i in names(x)
    if i == "col1" || i=="training" || occursin( "FILTER_Mutect",i)
        continue
    end
    if length(unique(x[:,i])) < 2 || occursin("Pindel",i) || occursin("Lofreq",i) || occursin("Vardict",i) # || occursin("ALT",i) || occursin("REF",i)
        push!(coldrop,i)
#         println(i)
    end 
end
unique!(coldrop)
select!(x, Not(coldrop));
println(sum([i==true for i in y]))
# println(nrow(xold))
# dropmissing!(xold)
# println(nrow(xold))
filter!(x->!ismissing(x.dust_score_Mutect),x);
println(size(y))
# println(length(sample_key2))
println()
y = y[x.col1]
# println(xold[findall(x->x,[i==true for i in yold]),"col1"])
# println(xold[findall(x->!x,[i==true for i in yold]),"col1"])
# sample_key2 = sample_key2[x.col1]
select!(x,Not("col1"));

println(size(x))
println(size(y))
# println(length(sample_key2))
println(sum([i==true for i in y]));
# Out:
# 15
# (6480,)
#
# (1196, 62)
# (1196,)
# 14

# %%
transform_log!(x,10)

# %%
stnd = fit_standardizer(x)
transform_standardizer!(x,stnd);

# %%
println(sum(ismissing.(Matrix(x))))
# Out:
# 35

# %%
imputemach = machine(MissingImputator(K=5),x) 
@time fit!(imputemach,verbosity=1)
# Out:
# ┌ Info: Training Machine{MissingImputator,…}.
# └ @ MLJBase /Users/alexpanchot/.julia/packages/MLJBase/HZmTU/src/machines.jl:403
#  16.515279 seconds (48.49 M allocations: 3.235 GiB, 5.38% gc time)
# Machine{MissingImputator,…} trained 1 time; caches data
#   args:
#     1:	Source @341 ⏎ `Table{Union{AbstractVector{Union{Missing, Continuous}}, AbstractVector{Continuous}}}`

# %%
tt = MLJ.transform(imputemach,x);
for i in 1:ncol(x)
    x[:,i] = tt[i]
end

# %%
disallowmissing!(x);

# %%
println(size(x)," ",sum([i==true for i in y] ) )
println(size(y))
# Out:
# (1196, 62) 14
# (1196,)

# %%
# x,y,train,test,sample_key = sampler(x,y,train,test,sample_key,"under",0.8);
# x,y,train,test,sample_key = sampler(x,y,train,test,sample_key,"over",0.2);

# %%
y = coerce(copy(y),OrderedFactor);

# %%
println(size(x)," ",sum([i==true for i in y] ) )
println(size(y))
# Out:
# (1196, 62) 14
# (1196,)

# %%
r = [range(LogisticClassifier(), :fit_intercept, values=[true,false]),
    range(LogisticClassifier(), :penalize_intercept, values=[true,false]),
    range(LogisticClassifier(), :penalty, values=[:none,:l1,:l2]),
    range(LogisticClassifier(), :lambda, lower=0.0,upper=1.0),
    range(LogisticClassifier(), :gamma, lower=0.0,upper=1.0),
]
# Out:
# 5-element Vector{MLJBase.ParamRange}:
#  NominalRange(fit_intercept = true, false)
#  NominalRange(penalize_intercept = true, false)
#  NominalRange(penalty = none, l1, l2)
#  NumericRange(0.0 ≤ lambda ≤ 1.0; origin=0.5, unit=0.5)
#  NumericRange(0.0 ≤ gamma ≤ 1.0; origin=0.5, unit=0.5)

# %%
self_tune = TunedModel(
#     model=LogisticClassifier(penalty=:l1),
    model=LogisticClassifier(),
    
    resampling=StratifiedCV(nfolds=5, rng=123),

    tuning=LatinHypercube(),  #     tuning=Grid(resolution=2), 
    range = r,
    n=200,
    operation=predict_mode, # use for probabalistic 
    measure = fnr,  # use for deterministic or with predict_mode for probab 
    acceleration=CPUThreads(),
)

machbest = machine(
    self_tune,
    x,y)
fit!(machbest,verbosity=1 )
# Out:
# ┌ Info: Training Machine{ProbabilisticTunedModel{LatinHypercube,…},…}.
# └ @ MLJBase /Users/alexpanchot/.julia/packages/MLJBase/HZmTU/src/machines.jl:403
# ┌ Info: Attempting to evaluate 200 models.
# └ @ MLJTuning /Users/alexpanchot/.julia/packages/MLJTuning/efiDR/src/tuned_models.jl:685
# Evaluating over 200 metamodels:   0%[>                        ]  ETA: N/A┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:   0%[>                        ]  ETA: 0:07:36┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:   4%[=>                       ]  ETA: 0:02:16┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:   8%[=>                       ]  ETA: 0:01:51┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  11%[==>                      ]  ETA: 0:01:16┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  14%[===>                     ]  ETA: 0:00:57┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  18%[====>                    ]  ETA: 0:01:03┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  22%[=====>                   ]  ETA: 0:00:53┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  26%[======>                  ]  ETA: 0:00:51┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  34%[========>                ]  ETA: 0:00:40┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  39%[=========>               ]  ETA: 0:00:35┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  52%[============>            ]  ETA: 0:00:28┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  55%[=============>           ]  ETA: 0:00:26┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  62%[===============>         ]  ETA: 0:00:22┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  62%[===============>         ]  ETA: 0:00:21┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  63%[===============>         ]  ETA: 0:00:21┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  64%[===============>         ]  ETA: 0:00:20┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  64%[================>        ]  ETA: 0:00:20┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  64%[================>        ]  ETA: 0:00:20┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  65%[================>        ]  ETA: 0:00:20┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  66%[================>        ]  ETA: 0:00:19┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  66%[================>        ]  ETA: 0:00:19┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  66%[================>        ]  ETA: 0:00:19┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  67%[================>        ]  ETA: 0:00:18┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  68%[================>        ]  ETA: 0:00:18┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  68%[=================>       ]  ETA: 0:00:18┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  68%[=================>       ]  ETA: 0:00:17┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  69%[=================>       ]  ETA: 0:00:17┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  70%[=================>       ]  ETA: 0:00:17┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  70%[=================>       ]  ETA: 0:00:16┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  71%[=================>       ]  ETA: 0:00:16┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  72%[==================>      ]  ETA: 0:00:15┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  72%[==================>      ]  ETA: 0:00:15┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  74%[==================>      ]  ETA: 0:00:14┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  74%[==================>      ]  ETA: 0:00:14┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  74%[==================>      ]  ETA: 0:00:14┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  75%[==================>      ]  ETA: 0:00:13┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  76%[==================>      ]  ETA: 0:00:13┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  76%[===================>     ]  ETA: 0:00:13┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  78%[===================>     ]  ETA: 0:00:12┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  79%[===================>     ]  ETA: 0:00:11┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  80%[===================>     ]  ETA: 0:00:11┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  80%[====================>    ]  ETA: 0:00:11┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  80%[====================>    ]  ETA: 0:00:10┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  81%[====================>    ]  ETA: 0:00:10┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  82%[====================>    ]  ETA: 0:00:10┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  82%[====================>    ]  ETA: 0:00:09┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  83%[====================>    ]  ETA: 0:00:09┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  84%[====================>    ]  ETA: 0:00:09┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  84%[=====================>   ]  ETA: 0:00:08┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  85%[=====================>   ]  ETA: 0:00:08┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  86%[=====================>   ]  ETA: 0:00:08┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  86%[=====================>   ]  ETA: 0:00:07┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  86%[=====================>   ]  ETA: 0:00:07┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  87%[=====================>   ]  ETA: 0:00:07┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  88%[=====================>   ]  ETA: 0:00:07┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  90%[======================>  ]  ETA: 0:00:05┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  90%[======================>  ]  ETA: 0:00:05┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  91%[======================>  ]  ETA: 0:00:05┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  92%[======================>  ]  ETA: 0:00:05┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  93%[=======================> ]  ETA: 0:00:04┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  94%[=======================> ]  ETA: 0:00:04┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  94%[=======================> ]  ETA: 0:00:03┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  94%[=======================> ]  ETA: 0:00:03┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  95%[=======================> ]  ETA: 0:00:03┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  96%[=======================> ]  ETA: 0:00:02┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  96%[========================>]  ETA: 0:00:02┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  96%[========================>]  ETA: 0:00:02┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  97%[========================>]  ETA: 0:00:02┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels: 100%[=========================] Time: 0:00:59
# Machine{ProbabilisticTunedModel{LatinHypercube,…},…} trained 1 time; caches data
#   args:
#     1:	Source @737 ⏎ `Table{AbstractVector{Continuous}}`
#     2:	Source @487 ⏎ `AbstractVector{OrderedFactor{2}}`

# %%
fitted_params(machbest).best_model
# Out:
# LogisticClassifier(
#     lambda = 0.964824120603015,
#     gamma = 0.4020100502512563,
#     penalty = :none,
#     fit_intercept = false,
#     penalize_intercept = true,
#     solver = nothing)

# %%
mach = machine(
    fitted_params(machbest).best_model,
    x,y)
fit!(mach,verbosity=4 )
# Out:
# ┌ Info: Training Machine{LogisticClassifier,…}.
# └ @ MLJBase /Users/alexpanchot/.julia/packages/MLJBase/HZmTU/src/machines.jl:403
# Machine{LogisticClassifier,…} trained 1 time; caches data
#   args:
#     1:	Source @077 ⏎ `Table{AbstractVector{Continuous}}`
#     2:	Source @227 ⏎ `AbstractVector{OrderedFactor{2}}`

# %%
FileIO.save("mutect$(full).jld2", Dict("mach"=>mach,"stnd" => stnd,
        "imputemach" => imputemach, 
    ) ; compress = true
)

# %% [markdown]
# # Vardict

# %%
x = copy(xold[train2,:]);
y = copy(yold[train2]);

# %%
x.col1=collect(1:nrow(x));
coldrop = [] #"FPpass","FILTER_Mutect_PASS"] # ["gt_AF_Mutect","AltFwd_Mutect","RefFwd_Mutect","AltRev_Mutect","RefRev_Mutect","gt_AD_ref_Mutect","gt_AD_alt_Mutect"]
for i in names(x)
    if i == "col1" || i=="training" || occursin( "FILTER_Vardict",i)
        continue
    end
    if length(unique(x[:,i])) < 2 || occursin("Pindel",i) || occursin("Lofreq",i) || occursin("Mutect",i) # || occursin("ALT",i) || occursin("REF",i)
        push!(coldrop,i)
#         println(i)
    end 
end
unique!(coldrop)
select!(x, Not(coldrop));
println(sum([i==true for i in y]))
# println(nrow(xold))
# dropmissing!(xold)
# println(nrow(xold))
filter!(x->!ismissing(x.dust_score_Vardict),x);
println(size(y))
# println(length(sample_key2))
println()
y = y[x.col1]
# println(xold[findall(x->x,[i==true for i in yold]),"col1"])
# println(xold[findall(x->!x,[i==true for i in yold]),"col1"])
# sample_key2 = sample_key2[x.col1]
select!(x,Not("col1"));

println(size(x))
println(size(y))
# println(length(sample_key2))
println(sum([i==true for i in y]));
# Out:
# 15
# (6480,)
#
# (935, 55)
# (935,)
# 15

# %%
transform_log!(x,10)
stnd = fit_standardizer(x)
transform_standardizer!(x,stnd);
println(sum(ismissing.(Matrix(x))))
# Out:
# 37

# %%
imputemach = machine(MissingImputator(K=5),x) 
@time fit!(imputemach,verbosity=1)
# Out:
# ┌ Info: Training Machine{MissingImputator,…}.
# └ @ MLJBase /Users/alexpanchot/.julia/packages/MLJBase/HZmTU/src/machines.jl:403
#   0.636282 seconds (3.20 M allocations: 467.790 MiB, 17.36% gc time, 30.82% compilation time)
# Machine{MissingImputator,…} trained 1 time; caches data
#   args:
#     1:	Source @725 ⏎ `Table{Union{AbstractVector{Union{Missing, Continuous}}, AbstractVector{Continuous}}}`

# %%
tt = MLJ.transform(imputemach,x);
for i in 1:ncol(x)
    x[:,i] = tt[i]
end
disallowmissing!(x);

# %%
println(size(x)," ",sum([i==true for i in y] ) )
println(size(y))
# x,y,train,test,sample_key = sampler(x,y,train,test,sample_key,"under",0.8);
# x,y,train,test,sample_key = sampler(x,y,train,test,sample_key,"over",0.2);

y = coerce(copy(y),OrderedFactor);

println(size(x)," ",sum([i==true for i in y] ) )
println(size(y))
# Out:
# (935, 55) 15
# (935,)
# (935, 55) 15
# (935,)

# %%
r = [range(LogisticClassifier(), :fit_intercept, values=[true,false]),
    range(LogisticClassifier(), :penalize_intercept, values=[true,false]),
    range(LogisticClassifier(), :penalty, values=[:none,:l1,:l2]),
    range(LogisticClassifier(), :lambda, lower=0.0,upper=1.0),
    range(LogisticClassifier(), :gamma, lower=0.0,upper=1.0),
]
# Out:
# 5-element Vector{MLJBase.ParamRange}:
#  NominalRange(fit_intercept = true, false)
#  NominalRange(penalize_intercept = true, false)
#  NominalRange(penalty = none, l1, l2)
#  NumericRange(0.0 ≤ lambda ≤ 1.0; origin=0.5, unit=0.5)
#  NumericRange(0.0 ≤ gamma ≤ 1.0; origin=0.5, unit=0.5)

# %%
self_tune = TunedModel(
#     model=LogisticClassifier(penalty=:l1),
    model=LogisticClassifier(),
    
    resampling=StratifiedCV(nfolds=5, rng=123),

    tuning=LatinHypercube(),  #     tuning=Grid(resolution=2), 
    range = r,
    n=200,
    operation=predict_mode, # use for probabalistic 
    measure = fnr,  # use for deterministic or with predict_mode for probab 
    acceleration=CPUThreads(),
)

machbest = machine(
    self_tune,
    x,y)
fit!(machbest,verbosity=1 )

mach = machine(
    fitted_params(machbest).best_model,
    x,y)
fit!(mach,verbosity=1 )
# Out:
# ┌ Info: Training Machine{ProbabilisticTunedModel{LatinHypercube,…},…}.
# └ @ MLJBase /Users/alexpanchot/.julia/packages/MLJBase/HZmTU/src/machines.jl:403
# ┌ Info: Attempting to evaluate 200 models.
# └ @ MLJTuning /Users/alexpanchot/.julia/packages/MLJTuning/efiDR/src/tuned_models.jl:685
# Evaluating over 200 metamodels:   0%[>                        ]  ETA: N/A┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:   0%[>                        ]  ETA: 0:02:45┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:   7%[=>                       ]  ETA: 0:00:35┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  18%[====>                    ]  ETA: 0:00:19┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  24%[=====>                   ]  ETA: 0:00:21┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  33%[========>                ]  ETA: 0:00:18┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  36%[=========>               ]  ETA: 0:00:18┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  46%[===========>             ]  ETA: 0:00:14┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  58%[==============>          ]  ETA: 0:00:10┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  59%[==============>          ]  ETA: 0:00:10┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  60%[==============>          ]  ETA: 0:00:10┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  60%[===============>         ]  ETA: 0:00:10┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  60%[===============>         ]  ETA: 0:00:10┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  61%[===============>         ]  ETA: 0:00:10┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  62%[===============>         ]  ETA: 0:00:10┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  62%[===============>         ]  ETA: 0:00:09┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  62%[===============>         ]  ETA: 0:00:09┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  63%[===============>         ]  ETA: 0:00:09┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  64%[================>        ]  ETA: 0:00:09┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  64%[================>        ]  ETA: 0:00:09┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  65%[================>        ]  ETA: 0:00:09┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  66%[================>        ]  ETA: 0:00:09┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  66%[================>        ]  ETA: 0:00:08┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  66%[================>        ]  ETA: 0:00:08┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  67%[================>        ]  ETA: 0:00:08┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  68%[=================>       ]  ETA: 0:00:08┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  68%[=================>       ]  ETA: 0:00:08┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  69%[=================>       ]  ETA: 0:00:08┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  70%[=================>       ]  ETA: 0:00:07┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  71%[=================>       ]  ETA: 0:00:07┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  72%[=================>       ]  ETA: 0:00:07┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  72%[==================>      ]  ETA: 0:00:07┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  72%[==================>      ]  ETA: 0:00:07┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  73%[==================>      ]  ETA: 0:00:07┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  75%[==================>      ]  ETA: 0:00:06┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  76%[==================>      ]  ETA: 0:00:06┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  76%[===================>     ]  ETA: 0:00:06┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  76%[===================>     ]  ETA: 0:00:06┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  77%[===================>     ]  ETA: 0:00:05┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  78%[===================>     ]  ETA: 0:00:05┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  78%[===================>     ]  ETA: 0:00:05┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  80%[===================>     ]  ETA: 0:00:05┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  80%[====================>    ]  ETA: 0:00:05┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  82%[====================>    ]  ETA: 0:00:04┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  84%[====================>    ]  ETA: 0:00:04┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  84%[=====================>   ]  ETA: 0:00:04┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  84%[=====================>   ]  ETA: 0:00:04┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  85%[=====================>   ]  ETA: 0:00:03┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  86%[=====================>   ]  ETA: 0:00:03┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  86%[=====================>   ]  ETA: 0:00:03┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  86%[=====================>   ]  ETA: 0:00:03┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  87%[=====================>   ]  ETA: 0:00:03┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  88%[======================>  ]  ETA: 0:00:03┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  88%[======================>  ]  ETA: 0:00:03┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  89%[======================>  ]  ETA: 0:00:03┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  90%[======================>  ]  ETA: 0:00:02┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  90%[======================>  ]  ETA: 0:00:02┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  90%[======================>  ]  ETA: 0:00:02┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  91%[======================>  ]  ETA: 0:00:02┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  92%[======================>  ]  ETA: 0:00:02┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  92%[=======================> ]  ETA: 0:00:02┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  94%[=======================> ]  ETA: 0:00:02┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  94%[=======================> ]  ETA: 0:00:01┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  94%[=======================> ]  ETA: 0:00:01┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  96%[=======================> ]  ETA: 0:00:01┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  96%[========================>]  ETA: 0:00:01┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  96%[========================>]  ETA: 0:00:01┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  97%[========================>]  ETA: 0:00:01┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  98%[========================>]  ETA: 0:00:01┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  98%[========================>]  ETA: 0:00:00┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels: 100%[========================>]  ETA: 0:00:00┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels: 100%[=========================] Time: 0:00:24
# ┌ Info: Training Machine{LogisticClassifier,…}.
# └ @ MLJBase /Users/alexpanchot/.julia/packages/MLJBase/HZmTU/src/machines.jl:403
# Machine{LogisticClassifier,…} trained 1 time; caches data
#   args:
#     1:	Source @074 ⏎ `Table{AbstractVector{Continuous}}`
#     2:	Source @453 ⏎ `AbstractVector{OrderedFactor{2}}`

# %%
FileIO.save("vardict$(full).jld2", Dict("mach"=>mach,"stnd" => stnd,
        "imputemach" => imputemach, 
    ) ; compress = true
)

# %% [markdown]
# # Lofreq

# %%
x = copy(xold[train2,:]);
y = copy(yold[train2]);

# %%
x.col1=collect(1:nrow(x));
coldrop = [] #"FPpass","FILTER_Mutect_PASS"] # ["gt_AF_Mutect","AltFwd_Mutect","RefFwd_Mutect","AltRev_Mutect","RefRev_Mutect","gt_AD_ref_Mutect","gt_AD_alt_Mutect"]
for i in names(x)
    if i == "col1" || i=="training" || occursin( "FILTER_Lofreq",i)
        continue
    end
    if length(unique(x[:,i])) < 2 || occursin("Pindel",i) || occursin("Vardict",i) || occursin("Mutect",i) # || occursin("ALT",i) || occursin("REF",i)
        push!(coldrop,i)
#         println(i)
    end 
end
unique!(coldrop)
select!(x, Not(coldrop));
println(sum([i==true for i in y]))
# println(nrow(xold))
# dropmissing!(xold)
# println(nrow(xold))
filter!(x->!ismissing(x.dust_score_Lofreq),x);
println(size(y))
# println(length(sample_key2))
println()
y = y[x.col1]
# println(xold[findall(x->x,[i==true for i in yold]),"col1"])
# println(xold[findall(x->!x,[i==true for i in yold]),"col1"])
# sample_key2 = sample_key2[x.col1]
select!(x,Not("col1"));

println(size(x))
println(size(y))
# println(length(sample_key2))
println(sum([i==true for i in y]));
# Out:
# 15
# (6480,)
#
# (452, 42)
# (452,)
# 15

# %%
transform_log!(x,10)
stnd = fit_standardizer(x)
transform_standardizer!(x,stnd);
println(sum(ismissing.(Matrix(x))))
# Out:
# 43

# %%
imputemach = machine(MissingImputator(K=5),x) 
@time fit!(imputemach,verbosity=1)
# Out:
# ┌ Info: Training Machine{MissingImputator,…}.
# └ @ MLJBase /Users/alexpanchot/.julia/packages/MLJBase/HZmTU/src/machines.jl:403
#   0.323016 seconds (2.05 M allocations: 251.178 MiB, 23.72% gc time)
# Machine{MissingImputator,…} trained 1 time; caches data
#   args:
#     1:	Source @169 ⏎ `Table{Union{AbstractVector{Union{Missing, Continuous}}, AbstractVector{Continuous}}}`

# %%
tt = MLJ.transform(imputemach,x);
for i in 1:ncol(x)
    x[:,i] = tt[i]
end
disallowmissing!(x);

# %%
println(size(x)," ",sum([i==true for i in y] ) )
println(size(y))
# x,y,train,test,sample_key = sampler(x,y,train,test,sample_key,"under",0.8);
# x,y,train,test,sample_key = sampler(x,y,train,test,sample_key,"over",0.2);

y = coerce(copy(y),OrderedFactor);

println(size(x)," ",sum([i==true for i in y] ) )
println(size(y))
# Out:
# (452, 42) 15
# (452,)
# (452, 42) 15
# (452,)

# %%
r = [range(LogisticClassifier(), :fit_intercept, values=[true,false]),
    range(LogisticClassifier(), :penalize_intercept, values=[true,false]),
    range(LogisticClassifier(), :penalty, values=[:none,:l1,:l2]),
    range(LogisticClassifier(), :lambda, lower=0.0,upper=1.0),
    range(LogisticClassifier(), :gamma, lower=0.0,upper=1.0),
]
# Out:
# 5-element Vector{MLJBase.ParamRange}:
#  NominalRange(fit_intercept = true, false)
#  NominalRange(penalize_intercept = true, false)
#  NominalRange(penalty = none, l1, l2)
#  NumericRange(0.0 ≤ lambda ≤ 1.0; origin=0.5, unit=0.5)
#  NumericRange(0.0 ≤ gamma ≤ 1.0; origin=0.5, unit=0.5)

# %%
self_tune = TunedModel(
#     model=LogisticClassifier(penalty=:l1),
    model=LogisticClassifier(),
    
    resampling=StratifiedCV(nfolds=5, rng=123),

    tuning=LatinHypercube(),  #     tuning=Grid(resolution=2), 
    range = r,
    n=200,
    operation=predict_mode, # use for probabalistic 
    measure = fnr,  # use for deterministic or with predict_mode for probab 
    acceleration=CPUThreads(),
)

machbest = machine(
    self_tune,
    x,y)
fit!(machbest,verbosity=1 )

mach = machine(
    fitted_params(machbest).best_model,
    x,y)
fit!(mach,verbosity=1 )
# Out:
# ┌ Info: Training Machine{ProbabilisticTunedModel{LatinHypercube,…},…}.
# └ @ MLJBase /Users/alexpanchot/.julia/packages/MLJBase/HZmTU/src/machines.jl:403
# ┌ Info: Attempting to evaluate 200 models.
# └ @ MLJTuning /Users/alexpanchot/.julia/packages/MLJTuning/efiDR/src/tuned_models.jl:685
# Evaluating over 200 metamodels:   0%[>                        ]  ETA: N/A┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:   0%[>                        ]  ETA: 0:00:20┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:   7%[=>                       ]  ETA: 0:00:15┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  18%[====>                    ]  ETA: 0:00:12┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  25%[======>                  ]  ETA: 0:00:10┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  33%[========>                ]  ETA: 0:00:11┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  38%[=========>               ]  ETA: 0:00:10┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  50%[============>            ]  ETA: 0:00:08┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  54%[=============>           ]  ETA: 0:00:07┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  62%[===============>         ]  ETA: 0:00:06┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  71%[=================>       ]  ETA: 0:00:04┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  78%[===================>     ]  ETA: 0:00:03┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  79%[===================>     ]  ETA: 0:00:03┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  80%[===================>     ]  ETA: 0:00:03┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  80%[====================>    ]  ETA: 0:00:03┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  80%[====================>    ]  ETA: 0:00:03┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  81%[====================>    ]  ETA: 0:00:03┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  82%[====================>    ]  ETA: 0:00:03┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  82%[====================>    ]  ETA: 0:00:03┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  82%[====================>    ]  ETA: 0:00:03┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  84%[====================>    ]  ETA: 0:00:02┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  84%[=====================>   ]  ETA: 0:00:02┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  86%[=====================>   ]  ETA: 0:00:02┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  86%[=====================>   ]  ETA: 0:00:02┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  86%[=====================>   ]  ETA: 0:00:02┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  87%[=====================>   ]  ETA: 0:00:02┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  88%[=====================>   ]  ETA: 0:00:02┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  88%[======================>  ]  ETA: 0:00:02┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  88%[======================>  ]  ETA: 0:00:02┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  89%[======================>  ]  ETA: 0:00:02┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  90%[======================>  ]  ETA: 0:00:02┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  90%[======================>  ]  ETA: 0:00:01┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  91%[======================>  ]  ETA: 0:00:01┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  92%[=======================> ]  ETA: 0:00:01┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  93%[=======================> ]  ETA: 0:00:01┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  94%[=======================> ]  ETA: 0:00:01┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  95%[=======================> ]  ETA: 0:00:01┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  99%[========================>]  ETA: 0:00:00┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels: 100%[=========================] Time: 0:00:17
# ┌ Info: Training Machine{LogisticClassifier,…}.
# └ @ MLJBase /Users/alexpanchot/.julia/packages/MLJBase/HZmTU/src/machines.jl:403
# Machine{LogisticClassifier,…} trained 1 time; caches data
#   args:
#     1:	Source @632 ⏎ `Table{AbstractVector{Continuous}}`
#     2:	Source @653 ⏎ `AbstractVector{OrderedFactor{2}}`

# %%
FileIO.save("lofreq$(full).jld2", Dict("mach"=>mach,"stnd" => stnd,
        "imputemach" => imputemach, 
    ) ; compress = true
)

# %% [markdown]
# # Pindel

# %%
x = copy(xold[train2,:]);
y = copy(yold[train2]);

# %%
! isonehot(unique(xold[:,"FILTER_Pindel_Not_Detected"])) && typeof(xold[findfirst(x->!ismissing(x),xold[:,"FILTER_Pindel_Not_Detected"]),"FILTER_Pindel_Not_Detected"]) <: Union{Float32, Float64}
# Out:
# false

# %%
x.col1=collect(1:nrow(x));
coldrop = [] #"FPpass","FILTER_Mutect_PASS"] # ["gt_AF_Mutect","AltFwd_Mutect","RefFwd_Mutect","AltRev_Mutect","RefRev_Mutect","gt_AD_ref_Mutect","gt_AD_alt_Mutect"]
for i in names(x)
    if i == "col1" || i=="training" || occursin( "FILTER_Pindel",i)
        continue
    end
    if length(unique(x[:,i])) < 2 || occursin("Lofreq",i) || occursin("Vardict",i) || occursin("Mutect",i) # || occursin("ALT",i) || occursin("REF",i)
        push!(coldrop,i)
#         println(i)
    end 
end
unique!(coldrop)
select!(x, Not(coldrop));
println(sum([i==true for i in y]))
# println(nrow(xold))
# dropmissing!(xold)
# println(nrow(xold))
filter!(x->!ismissing(x.dust_score_Pindel),x);
println(size(y))
# println(length(sample_key2))
println()
y = y[x.col1]
# println(xold[findall(x->x,[i==true for i in yold]),"col1"])
# println(xold[findall(x->!x,[i==true for i in yold]),"col1"])
# sample_key2 = sample_key2[x.col1]
select!(x,Not("col1"));

println(size(x))
println(size(y))
# println(length(sample_key2))
println(sum([i==true for i in y]));
# Out:
# 15
# (6480,)
#
# (5027, 32)
# (5027,)
# 15

# %%
transform_log!(x,10)
stnd = fit_standardizer(x)
transform_standardizer!(x,stnd);
println(sum(ismissing.(Matrix(x))))
# Out:
# 3658

# %%
imputemach = machine(MissingImputator(K=5),x) 
@time fit!(imputemach,verbosity=1)
# Out:
# ┌ Info: Training Machine{MissingImputator,…}.
# └ @ MLJBase /Users/alexpanchot/.julia/packages/MLJBase/HZmTU/src/machines.jl:403
#   8.238136 seconds (62.15 M allocations: 6.089 GiB, 17.85% gc time)
# Machine{MissingImputator,…} trained 1 time; caches data
#   args:
#     1:	Source @665 ⏎ `Table{Union{AbstractVector{Union{Missing, Continuous}}, AbstractVector{Continuous}}}`

# %%
tt = MLJ.transform(imputemach,x);
for i in 1:ncol(x)
    x[:,i] = tt[i]
end
disallowmissing!(x);

# %%
println(size(x)," ",sum([i==true for i in y] ) )
println(size(y))
# x,y,train,test,sample_key = sampler(x,y,train,test,sample_key,"under",0.8);
# x,y,train,test,sample_key = sampler(x,y,train,test,sample_key,"over",0.2);

y = coerce(copy(y),OrderedFactor);

println(size(x)," ",sum([i==true for i in y] ) )
println(size(y))
# Out:
# (5027, 32) 15
# (5027,)
# (5027, 32) 15
# (5027,)

# %%
r = [range(LogisticClassifier(), :fit_intercept, values=[true,false]),
    range(LogisticClassifier(), :penalize_intercept, values=[true,false]),
    range(LogisticClassifier(), :penalty, values=[:none,:l1,:l2]),
    range(LogisticClassifier(), :lambda, lower=0.0,upper=1.0),
    range(LogisticClassifier(), :gamma, lower=0.0,upper=1.0),
]
# Out:
# 5-element Vector{MLJBase.ParamRange}:
#  NominalRange(fit_intercept = true, false)
#  NominalRange(penalize_intercept = true, false)
#  NominalRange(penalty = none, l1, l2)
#  NumericRange(0.0 ≤ lambda ≤ 1.0; origin=0.5, unit=0.5)
#  NumericRange(0.0 ≤ gamma ≤ 1.0; origin=0.5, unit=0.5)

# %%
self_tune = TunedModel(
#     model=LogisticClassifier(penalty=:l1),
    model=LogisticClassifier(),
    
    resampling=StratifiedCV(nfolds=5, rng=123),

    tuning=LatinHypercube(),  #     tuning=Grid(resolution=2), 
    range = r,
    n=200,
    operation=predict_mode, # use for probabalistic 
    measure = fnr,  # use for deterministic or with predict_mode for probab 
    acceleration=CPUThreads(),
)

machbest = machine(
    self_tune,
    x,y)
fit!(machbest,verbosity=1 )

mach = machine(
    fitted_params(machbest).best_model,
    x,y)
fit!(mach,verbosity=1 )
# Out:
# ┌ Info: Training Machine{ProbabilisticTunedModel{LatinHypercube,…},…}.
# └ @ MLJBase /Users/alexpanchot/.julia/packages/MLJBase/HZmTU/src/machines.jl:403
# ┌ Info: Attempting to evaluate 200 models.
# └ @ MLJTuning /Users/alexpanchot/.julia/packages/MLJTuning/efiDR/src/tuned_models.jl:685
# Evaluating over 200 metamodels:   0%[>                        ]  ETA: N/A┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:   0%[>                        ]  ETA: 0:03:39┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:   7%[=>                       ]  ETA: 0:02:15┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  12%[===>                     ]  ETA: 0:02:01┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  20%[=====>                   ]  ETA: 0:02:01┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  24%[=====>                   ]  ETA: 0:01:43┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  31%[=======>                 ]  ETA: 0:01:35┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  38%[=========>               ]  ETA: 0:01:22┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  41%[==========>              ]  ETA: 0:01:14┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  50%[============>            ]  ETA: 0:01:05┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  58%[==============>          ]  ETA: 0:00:53┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  68%[================>        ]  ETA: 0:00:37┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  68%[=================>       ]  ETA: 0:00:37┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  68%[=================>       ]  ETA: 0:00:37┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  69%[=================>       ]  ETA: 0:00:37┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  70%[=================>       ]  ETA: 0:00:36┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  70%[=================>       ]  ETA: 0:00:35┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  70%[=================>       ]  ETA: 0:00:34┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  71%[=================>       ]  ETA: 0:00:34┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  72%[==================>      ]  ETA: 0:00:32┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  72%[==================>      ]  ETA: 0:00:32┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  73%[==================>      ]  ETA: 0:00:31┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  74%[==================>      ]  ETA: 0:00:30┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  74%[==================>      ]  ETA: 0:00:30┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  74%[==================>      ]  ETA: 0:00:29┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  75%[==================>      ]  ETA: 0:00:29┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  76%[==================>      ]  ETA: 0:00:28┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  76%[===================>     ]  ETA: 0:00:27┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  76%[===================>     ]  ETA: 0:00:27┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  78%[===================>     ]  ETA: 0:00:26┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  78%[===================>     ]  ETA: 0:00:25┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  79%[===================>     ]  ETA: 0:00:24┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  80%[====================>    ]  ETA: 0:00:23┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  80%[====================>    ]  ETA: 0:00:22┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  81%[====================>    ]  ETA: 0:00:21┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  82%[====================>    ]  ETA: 0:00:21┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  82%[====================>    ]  ETA: 0:00:21┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  83%[====================>    ]  ETA: 0:00:20┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  84%[====================>    ]  ETA: 0:00:19┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  84%[=====================>   ]  ETA: 0:00:18┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  86%[=====================>   ]  ETA: 0:00:16┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  86%[=====================>   ]  ETA: 0:00:15┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  87%[=====================>   ]  ETA: 0:00:15┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  88%[=====================>   ]  ETA: 0:00:15┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  88%[======================>  ]  ETA: 0:00:14┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  88%[======================>  ]  ETA: 0:00:14┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  89%[======================>  ]  ETA: 0:00:13┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  90%[======================>  ]  ETA: 0:00:13┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  90%[======================>  ]  ETA: 0:00:12┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  91%[======================>  ]  ETA: 0:00:11┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  92%[======================>  ]  ETA: 0:00:10┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  92%[=======================> ]  ETA: 0:00:10┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  92%[=======================> ]  ETA: 0:00:09┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  93%[=======================> ]  ETA: 0:00:09┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  94%[=======================> ]  ETA: 0:00:08┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  95%[=======================> ]  ETA: 0:00:06┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  96%[=======================> ]  ETA: 0:00:06┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  96%[========================>]  ETA: 0:00:05┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# ┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  97%[========================>]  ETA: 0:00:04┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  98%[========================>]  ETA: 0:00:03┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels:  98%[========================>]  ETA: 0:00:02┌ Warning: Proximal GD did not converge in 1000 iterations.
# └ @ MLJLinearModels /Users/alexpanchot/.julia/packages/MLJLinearModels/ISbgA/src/fit/proxgrad.jl:64
# Evaluating over 200 metamodels: 100%[=========================] Time: 0:02:04
# ┌ Info: Training Machine{LogisticClassifier,…}.
# └ @ MLJBase /Users/alexpanchot/.julia/packages/MLJBase/HZmTU/src/machines.jl:403
# Machine{LogisticClassifier,…} trained 1 time; caches data
#   args:
#     1:	Source @102 ⏎ `Table{AbstractVector{Continuous}}`
#     2:	Source @928 ⏎ `AbstractVector{OrderedFactor{2}}`

# %%
FileIO.save("pindel$(full).jld2", Dict("mach"=>mach,"stnd" => stnd,
        "imputemach" => imputemach, 
    ) ; compress = true
)

# %%
[println(i) for i in sort(fitted_params(mach).coefs)];
# Out:
# :FILTER_Pindel_Not_Detected => 0.0
# :FILTER_Pindel_PASS => -130.4613821922679
# :FPpass => 13.329990243672464
# :SYMBOL_ASXL1 => -26.238394207305987
# :SYMBOL_CHEK2 => -13.868052703970669
# :SYMBOL_DNMT3A => 3.5615043359747736
# :SYMBOL_JAK2 => -1.0049313553598238
# :SYMBOL_PPM1D => -13.466080161821631
# :SYMBOL_SF3B1 => -12.327157959080598
# :SYMBOL_SRSF2 => -7.502877970367554
# :SYMBOL_TET2 => -38.947303961611006
# :SYMBOL_TP53 => -20.668088208567028
# Symbol("VARIANT_CLASS_DUP:TANDEM") => -1.9763649988743182
# :VARIANT_CLASS_INV => -4.120218557027703
# :VARIANT_CLASS_RPL => -22.54960778870932
# :VARIANT_CLASS_deletion => -12.471551368495891
# :VARIANT_CLASS_indel => -31.769932453479907
# :VARIANT_CLASS_insertion => -8.265075189357315
# :VARIANT_CLASS_substitution => -49.30863183632207
# :alt_len => -64.46199391134682
# :dust_score_10_Pindel => -31.189935676735544
# :dust_score_3_Pindel => 6.653781143273521
# :dust_score_5_Pindel => -31.13218857184306
# :dust_score_Pindel => -38.91703392869214
# :gt_AD_alt_Pindel => 17.7334212870764
# :gt_AD_ref_Pindel => -8.507928273254274
# :gt_AF_Pindel => -1.5190512043298638
# :pass_homopolymer_filter => -114.07126217213556
# :pon_pvalue_Pindel => -21.359009677088626
# :ref_len => -47.79114689558692
# :total_Pindel => -32.647462970845126
# :total_greater_than_min_alt_count_Pindel => 61.667385605411845

# %%
# run(`zip caller_predictions/data_full.zip data_full.jld2`)
# Out:
# 	zip warning: name not matched: data_full.jld2
#
# zip error: Nothing to do! (caller_predictions/data_full.zip)
# failed process: Process(`zip caller_predictions/data_full.zip data_full.jld2`, ProcessExited(12)) [12]
#
#
# Stacktrace:
#  [1] pipeline_error
#    @ ./process.jl:525 [inlined]
#  [2] run(::Cmd; wait::Bool)
#    @ Base ./process.jl:440
#  [3] run(::Cmd)
#    @ Base ./process.jl:438
#  [4] top-level scope
#    @ In[459]:1
#  [5] eval
#    @ ./boot.jl:360 [inlined]
#  [6] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116
